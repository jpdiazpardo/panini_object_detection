# %% [markdown]
# # Install dependencies

# %%
# !pip install --user --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/ubuntu/.local/lib/python3.8/site-packages (22.2.2)

# %%
# !pip install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cu111
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/lts/1.8/cu111
# Requirement already satisfied: torch==1.8.2 in /opt/conda/lib/python3.8/site-packages (1.8.2+cu111)
# Requirement already satisfied: torchvision==0.9.2 in /opt/conda/lib/python3.8/site-packages (0.9.2+cu111)
# Requirement already satisfied: torchaudio===0.8.2 in /opt/conda/lib/python3.8/site-packages (0.8.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch==1.8.2) (3.7.4.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from torch==1.8.2) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/lib/python3.8/site-packages (from torchvision==0.9.2) (8.2.0)

# %%
# !pip install --user easyocr --quiet

# %%
# !pip install -r yolov5/requirements.txt --quiet

# %% [markdown]
# # Clone yolov5 repository

# %%
#!git clone https://github.com/ultralytics/yolov5

# %% [markdown]
# # Import dependencies

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
import os
import easyocr

# %%
#Download easy ocr reader
reader = easyocr.Reader(['en'])
# Out:
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |--------------------------------------------------| 1.6% Complete
# Progress: |█████---------------------------------------------| 11.4% Complete
# Progress: |████████████--------------------------------------| 24.5% Complete
# Progress: |███████████████████-------------------------------| 38.6% Complete
# Progress: |███████████████████████████-----------------------| 54.1% Complete
# Progress: |██████████████████████████████████----------------| 69.7% Complete
# Progress: |██████████████████████████████████████████--------| 85.2% Complete
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %% [markdown]
# # Train model

# %%
#Validate GPU device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
#!python yolov5/train.py --batch 16 --epochs 500 --data yolov5/dataset.yml --weights yolov5s.pt

# %% [markdown]
# # Load model and predict

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path = 'yolov5/runs/train/exp/weights/last.pt', force_reload = True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /home/ubuntu/.cache/torch/hub/master.zip
# YOLOv5 🚀 2022-9-23 Python-3.8.8 torch-1.8.2+cu111 CUDA:0 (NVIDIA A10G, 22732MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %% [markdown]
# ### View examples

# %%
# %matplotlib inline

for i in range(1,9):
    img = os.path.join('data','images','s-l500 ('+str(i)+').png')
    results = model(img)
    results.print()
    plt.imshow(np.squeeze(results.render()))
    plt.show()
# Out:
# image 1/1: 500x398 1 panini, 1 name
# Speed: 17.1ms pre-process, 11.6ms inference, 1.4ms NMS per image at shape (1, 3, 640, 512)
# image 1/1: 500x390 1 panini, 1 name
# Speed: 15.8ms pre-process, 7.9ms inference, 1.1ms NMS per image at shape (1, 3, 640, 512)
# image 1/1: 500x405 1 panini, 1 name
# Speed: 16.4ms pre-process, 11.4ms inference, 1.2ms NMS per image at shape (1, 3, 640, 544)
# image 1/1: 500x389 1 panini, 1 name
# Speed: 15.8ms pre-process, 8.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 512)
# image 1/1: 500x396 1 panini, 1 name
# Speed: 15.8ms pre-process, 8.2ms inference, 1.2ms NMS per image at shape (1, 3, 640, 512)
# image 1/1: 500x401 1 panini, 1 name
# Speed: 16.2ms pre-process, 8.5ms inference, 1.1ms NMS per image at shape (1, 3, 640, 544)
# image 1/1: 500x392 1 panini, 1 name
# Speed: 15.7ms pre-process, 8.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 512)
# image 1/1: 500x391 1 panini, 1 name
# Speed: 15.8ms pre-process, 8.0ms inference, 1.1ms NMS per image at shape (1, 3, 640, 512)

# %% [markdown]
# # Label images using OCR

# %%
img = os.path.join('data','images','s-l225 (1).jpg')
results = model(img)
results.print()
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# image 1/1: 225x191 1 panini, 1 name
# Speed: 3.8ms pre-process, 8.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 544)

# %%
#Get predictions
pred = results.pred[0].tolist()

# %%
#Filter scores 
all_scores = [pred[s][-2] for s in range(0,len(pred)) if len(pred)==2 and pred[s][-1]==16]

#Filter boxes
all_boxes = [pred[s][0:4] for s in range(0,len(pred)) if len(pred)==2 and pred[s][-1]==16]

#Filter classes
all_classes = [pred[s][-1] for s in range(0,len(pred)) if len(pred)==2 and pred[s][-1]==16]

# %%
detection_threshold = 0.7
scores = list(filter(lambda x: x>detection_threshold, all_scores))
boxes = all_boxes[:len(scores)][0]
classes = all_classes[:len(scores)]

# %% [markdown]
# ### Crop image

# %%
cropped_image = cv2.imread('data/images/s-l225 (1).jpg')[int(boxes[1]):int(boxes[3]), int(boxes[0]):int(boxes[2])]
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
ocr_result =  reader.readtext(cropped_image)

# %% [markdown]
# ### Run optical character recognition (OCR)

# %%
ocr_result =  reader.readtext(cropped_image)
print(ocr_result[0][1])
# Out:
# CRISTIANO RONALDO

# %% [markdown]
# ### Putting all together

# %%
f, axarr = plt.subplots(1,2, figsize=(10, 10)) #Create subplts
axarr[0].imshow(np.squeeze(results.render())) #Load image with detections
axarr[1].imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)) #Load cropped image
axarr[1].set_title(ocr_result[0][1], fontsize=17) #Set title based on OCR
# Out:
# Text(0.5, 1.0, 'CRISTIANO RONALDO')

# %% [markdown]
# # Detect on live footage

# %%
#!python yolov5/detect.py --conf-thres 0.7 --source data/videos/WIN_20220919_15_36_24_Pro.mp4 --weights yolov5/runs/train/exp/weights/last.pt
